# %% [markdown]
# <br/> <br/> <br/> <br/> <br/> <br/> <br/> <br/> <br/> <br/> <br/>

# %% [markdown]
# # <center>《无线通信中的人工智能》案例实践报告 </center>

# %% [markdown]
# ### <center>专业：$\underline{\quad\quad通信工程\quad\quad}$</center>
#
# ### <center>班级：$\underline{\quad\,2018211129\quad\,}$</center>
#
# ### <center>学号：$\underline{\quad\,2018210071\quad\,}$</center>
#
# ### <center>姓名：$\underline{\quad\quad\,骆禹松\quad\quad\,}$</center>

# %% [markdown]
# ### <center>2020年11月18日</center>

# %% [markdown]
# <br/> <br/> <br/> <br/> <br/> <br/> <br/> <br/> <br/> <br/> <br/>

# %% [markdown]
# # <center>实验平台搭建</center>

# %% [markdown]
# ## 一、实验目的

# %% [markdown]
# &emsp;&emsp;Matlab是一套功能强大的工程计算软件，它具有高效的数值计算及符号计算功能，能使用户从复杂的数学运算分析中解脱出来。Python是当下的主流语言，它具有上手简单功能强大等特点。这两者可以简化我们的数学运算过程，将两种技术应用子在通信系统中，可以让工作效率大大提高。为了使用这两个工具完成接下来的一系列任务，我需要搭建一套实验平台，即在电脑上安装Matlab、Anaconda、Pycharm并配置环境等。

# %% [markdown]
# ## 二、实验内容

# %% [markdown]
# ### 1. Matlab的安装

# %% [markdown]
# &emsp;&emsp;通过信息门户的正版软件平台安装Matlab R2019a（在之前的课程学习中已经安装并配置完毕）。

# %% [markdown]
# ### 2. Anaconda的安装

# %% [markdown]
# &emsp;&emsp;安装Anaconda并配置环境（在之前的课程学习中已经安装并配置完毕）。

# %% [markdown]
# ### 3. Pycharm的安装

# %% [markdown]
# &emsp;&emsp;安装Pycharm并配置环境。因为我平常用Pycharm比较多，所以这里我额外安装了Pycharm（在之前的课程学习中已经安装并配置完毕）。

# %% [markdown]
# ### 4. Tensorflow的配置

# %% [markdown]
# &emsp;&emsp;在Python环境中安装Tensorflow（在之前的课程学习中已经配置完毕）。

# %% [markdown]
# ### 5. Keras的配置

# %% [markdown]
# &emsp;&emsp;在Python环境中安装Keras（在之前的课程学习中已经配置完毕）。

# %% [markdown]
# ### 6. 创建新的虚拟环境

# %% [markdown]
# &emsp;&emsp;创建一个新的虚拟环境，因为我平常用Pycharm比较多，所以这里直接在Pycharm中创建新的虚拟环境（在之前的课程学习中已经创建完毕）。

# %% [markdown]
# ### 7. 学习Jupyter Notebook的使用

# %% [markdown]
# &emsp;&emsp;掌握Jupyter Notebook的基本使用方法。

# %% [markdown]
# ## 三、实验步骤及实验结果

# %% [markdown]
# ### 1. Matlab的安装及版本检测

# %% [markdown]
# &emsp;&emsp;从下图中可以看出，Matlab R2019a已经成功安装。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 2. Anaconda的安装

# %% [markdown]
# &emsp;&emsp;从下图中可以看出，Anaconda已经安装完毕。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 3. Pycharm的安装

# %% [markdown]
# &emsp;&emsp;从下图可以看出，Pycharm已经安装成功。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 4. Tensorflow的配置

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.3.0'

# %% [markdown]
# ### 5. Keras的配置

# %%
import keras
keras.__version__
# Out:
# Using TensorFlow backend.
# '2.3.1'

# %% [markdown]
# ### 6. 创建新的虚拟环境

# %% [markdown]
# &emsp;&emsp;因为我使用Pycharm比较多，所以我通常在Pycharm里创建新的虚拟环境。下图所示是我在创建新项目时的可用环境列表。

# %% [markdown]
# &emsp;&emsp;环境说明：
#
# &emsp;&emsp;&emsp;&emsp; Python 3.6(venv): Python 3.6版本对应的虚拟环境，其中安装了Tensorflow 1.14.0。
#
# &emsp;&emsp;&emsp;&emsp; Python 3.8(venv)(2): Spyder的环境，Python版本为3.8。
#
# &emsp;&emsp;&emsp;&emsp; Python 3.8(venv)(3): 我的常用环境，Python版本为3.8，其中安装了Tensorflow2.3.0和Keras2.3.1等，此Jupyter Notebook所使用的就是这个环境。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 7. 学习Jupyter Notebook的使用

# %% [markdown]
# &emsp;&emsp; 通过查阅资料和不断实践，我掌握了Jupyter Notebook的基本使用方法，如Markdown文本的编写、在Jupyter Notebook中运行程序、更改打开时的默认文件夹、切换Jupyter Notebook所使用的环境等。
#
# &emsp;&emsp; 这篇实践报告就是在Jupyter Notebook中编写的，这是对我学习成果的证明。

# %% [markdown]
# ## 四、实验总结

# %% [markdown]
# &emsp;&emsp;通过本次实验，我安装并配置好了Matlab R2019a和Python的环境及编译器等，并安装了之后的实验所需的库文件，如Tensorflow、Keras等。因为大部分工作在之前的一些专业课程中早已完成，所以本次实验过程中并未遇到太多阻碍，接下来就是利用已有的平台来完成各种实验了！
